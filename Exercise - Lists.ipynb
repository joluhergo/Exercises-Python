# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1. Given the list:

# %%
lst = [1, 2, 34, 5, 3, 12, 9, 8, 67, 89, 98, 90, 39, 21, 45, 46, 23, 13]

# %% [markdown]
# Answer the following questions:

# %% [markdown]
# #### - How many elements are in the list?

# %%
len(lst)
# Out:
# 18

# %% [markdown]
# There are 18 elements in the list

# %% [markdown]
# #### - Using indexes, find out which is the first element in the list?

# %%
lst[0]
# Out:
# 1

# %% [markdown]
# The first element is 1

# %% [markdown]
# #### - Using indexes, find out which is the last element in the list?

# %%
lst[len(lst)-1]
# Out:
# 13

# %% [markdown]
# The last element is 13

# %% [markdown]
# #### - What is the index of element 90 in the list?

# %%
lst.index(90)
# Out:
# 11

# %% [markdown]
# The index of element 90 is 11, starting from 0

# %% [markdown]
# ####  - Which are the first 8 elements in the list?

# %%
lst[:8]
# Out:
# [1, 2, 34, 5, 3, 12, 9, 8]

# %% [markdown]
# #### - Append elements 100 and 110 to the list?

# %%
lst.append(100)

# %%
lst.append(110)

# %%
lst
# Out:
# [1, 2, 34, 5, 3, 12, 9, 8, 67, 89, 98, 90, 39, 21, 45, 46, 23, 13, 100, 110]

# %% [markdown]
# ### 1.2 Can a list have two or more elements that are same? Try and test. Try to define a new list with a few similar values and see if it work

# %%
lst_2 = [1,1,2,1,2,2,3,1,2,3,1]

# %%
len(lst_2)
# Out:
# 11

# %%
lst_2[0]
# Out:
# 1

# %%
lst_2[:4]
# Out:
# [1, 1, 2, 1]

# %%
lst_2[2:5]
# Out:
# [2, 1, 2]

# %% [markdown]
# Yes, a list can have two or more elements that are the same, it works exactly the same
