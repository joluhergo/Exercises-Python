# %%
# Exercise 1. Variables


# For the following variables, use the function type() from Python to check the data type for the variables.

# %%
x1 = 1.1
x2 = "Ironhack"
x3 = "1.1"
x4 = True
x5 = "True"
x6 = -1

# %%
type(x1)
# Out:
# float

# %%
type(x2)
# Out:
# str

# %%
type(x3)
# Out:
# str

# %%
type(x4)
# Out:
# bool

# %%
type(x5)
# Out:
# str

# %%
type(x6)
# Out:
# int

# %%
# 1.2 What is the difference between variables x1 and x3?

# x1 is a float variable and x3 is a string variable

# %%
# 1.3 What is the difference between variables x4 and x5?

# x4 is a boolean variable and  x5 is a string variable

# %%
# 2. Exercise - Operators

# 2.1 In this problem we will show you how to take a user input. Use the code and then answer the questions that follow:

# %%
x1 = input("Please enter an integer number: ")

x2 = input("Please enter another integer number")
# Out:
# Please enter an integer number:  1
# Please enter another integer number 2

# %%
# Question 1: Print the values of the two variables?

# %%
x1, x2
# Out:
# ('1', '2')

# %%
# As you might have noticed, data type of x1 and x2 is string. 
# Even though we entered integers, the input function converts them into string by default. 
# Now we do some data type conversion from string to integers:

# %%
x1 = int(x1) # This converts string into integer and re-initializes `x1`
x2 = int(x2) # This converts string into integer and re-initializes `x2`

# %%
# Question 2: What is the data type of x1 and x2?

# %%
x1,type(x1), x2, type (x2)
# Out:
# (1, int, 2, int)

# %%
# Now data type of x1 and x2 is integer.

# %%
# Check if the two variables are equal?
x1 == x2
# Out:
# False

# %%
# Check if x1 is greater than x2?
x1 > x2
# Out:
# False

# %%
# Check if x2 is greater than x1?
x2 > x1
# Out:
# True

# %%
# Check if x1 is not equal to x2?
x1 != x2
# Out:
# True

# %%
# Store the difference between the two variables x1 and x2 in another variable x3 
# (subtract the smaller number from the larger number).

x3 = x2-x1

# %%
# Increment the smaller of the two variables (x1 and x2) with the difference.
# Use the shorthand addition operator for the same. Again check if x1 and x2 are equal or not?

x1 += x3

# %%
x1 == x2
# Out:
# True

# %%
# 2.2 In the lesson, we talked about math library in Python. 
# Here is a link to the math library documentation. 
# Go through the documentation and try any 3 or more functions on a numerical variable that were not described in the lesson.

# %%
import math

# %%
math.factorial(10)
# Out:
# 3628800

# %%
math.isqrt(10)
# Out:
# 3

# %%
math.exp(10)
# Out:
# 22026.465794806718
