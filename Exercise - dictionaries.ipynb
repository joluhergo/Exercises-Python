# %% [markdown]
# # Exercise - dictionaries

# %% [markdown]
# ### 1.1 You are given this dictionary

# %%
word_freq = {
  'love': 25,
  'conversation': 1,
  'every': 6,
  "we're": 1,
  'plate': 1,
  'sour': 1,
  'jukebox': 1,
  'now': 11,
  'taxi': 1,
  'fast': 1,
  'bag': 1,
  'man': 1,
  'push': 3,
  'baby': 14,
  'going': 1,
  'you': 16,
  "don't": 2,
  'one': 1,
  'mind': 2,
  'backseat': 1,
  'friends': 1,
  'then': 3,
  'know': 2
}

# %% [markdown]
# ### Answer the following questions

# %% [markdown]
# ##### How many key-value pairs are in this dictionary?

# %%
len(word_freq.keys())
# Out:
# 23

# %% [markdown]
# ##### What keys are present in this list?

# %%
word_freq.keys()
# Out:
# dict_keys(['love', 'conversation', 'every', "we're", 'plate', 'sour', 'jukebox', 'now', 'taxi', 'fast', 'bag', 'man', 'push', 'baby', 'going', 'you', "don't", 'one', 'mind', 'backseat', 'friends', 'then', 'know'])

# %% [markdown]
# ##### What is the frequency of following words in the dictionary:

# %% [markdown]
# ###### - friends

# %%
word_freq['friends']
# Out:
# 1

# %% [markdown]
# ###### - taxi

# %%
word_freq['taxi']
# Out:
# 1

# %% [markdown]
# ###### - jukebox

# %%
word_freq['jukebox']
# Out:
# 1

# %% [markdown]
# ##### Is the word begin present in the dictionary?

# %%
word_freq['begin']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-20b1011d6422> in <module>
# ----> 1 word_freq['begin']
#
# KeyError: 'begin'

# %% [markdown]
# 'begin' is not present in the dictionary

# %% [markdown]
# ##### Add the following words and their frequencies to the dictionary:

# %% [markdown]
# ###### ‘begin’: 1

# %%
word_freq['begin'] = 1
word_freq['begin'] # to check if it has been included correctly
# Out:
# 1

# %% [markdown]
# ###### ‘start’: 2

# %%
word_freq['start'] = 2
word_freq['start']
# Out:
# 2

# %% [markdown]
# ###### ‘over’: 1

# %%
word_freq['over'] = 1
word_freq['over']
# Out:
# 1

# %% [markdown]
# ###### ‘body’: 17

# %%
word_freq['body'] = 17
word_freq['body']
# Out:
# 17

# %% [markdown]
# ##### Use the following code to convert the result from word_freq.keys() to a list: list(word_freq.keys())

# %%
list(word_freq.keys())
# Out:
# ['love',
#  'conversation',
#  'every',
#  "we're",
#  'plate',
#  'sour',
#  'jukebox',
#  'now',
#  'taxi',
#  'fast',
#  'bag',
#  'man',
#  'push',
#  'baby',
#  'going',
#  'you',
#  "don't",
#  'one',
#  'mind',
#  'backseat',
#  'friends',
#  'then',
#  'know',
#  'begin',
#  'start',
#  'over',
#  'body']

# %% [markdown]
# ##### Store the results of the above code in a variable called word.

# %%
word = list(word_freq.keys())
word
# Out:
# ['love',
#  'conversation',
#  'every',
#  "we're",
#  'plate',
#  'sour',
#  'jukebox',
#  'now',
#  'taxi',
#  'fast',
#  'bag',
#  'man',
#  'push',
#  'baby',
#  'going',
#  'you',
#  "don't",
#  'one',
#  'mind',
#  'backseat',
#  'friends',
#  'then',
#  'know',
#  'begin',
#  'start',
#  'over',
#  'body']

# %% [markdown]
# ##### What is the first word in the dictionary? What is the frequency of that word?

# %%
word[0]
# Out:
# 'love'

# %%
word_freq[word[0]]
# Out:
# 25

# %% [markdown]
# ##### What is the last word in the dictionary? What is the frequency of that word?

# %%
word[len(word)-1]
# Out:
# 'body'

# %%
word_freq['body']
# Out:
# 17

# %% [markdown]
# ##### Can a dictionary have two key-value pairs with the same key?

# %% [markdown]
# No:

# %% [markdown]
# If we define
# word_freq['love'] = 1 ,
# it would change the value of 'love', but it would not include another second key called 'love' in word_freq dictionary

# %% [markdown]
# ##### Can a dictionary have two key-value pairs with the same value but different keys?

# %% [markdown]
# Yes:

# %%
word_freq.values()
# Out:
# dict_values([25, 1, 6, 1, 1, 1, 1, 11, 1, 1, 1, 1, 3, 14, 1, 16, 2, 1, 2, 1, 1, 3, 2, 1, 2, 1, 17])

# %% [markdown]
# several keys have the same value (1) in word_freq

# %%
# Checking the previous answer:
word_freq['love'] = 1 
word_freq.values()
# Out:
# dict_values([1, 1, 6, 1, 1, 1, 1, 11, 1, 1, 1, 1, 3, 14, 1, 16, 2, 1, 2, 1, 1, 3, 2, 1, 2, 1, 17])
