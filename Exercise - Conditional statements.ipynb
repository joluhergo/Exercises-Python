# %% [markdown]
# # Exercises - Conditional statements

# %% [markdown]
# 1.1 Ask the user to input a number (should be integer). Check if the number is even or odd. Remember that 0 is neither even nor odd.

# %%
a = input ("Enter an integer number: ")
a = int(a)

if a == 0:
    print(f"0 is neither even nor odd")
elif a % 2 == 0:
    print(f"The numberis even")
elif a % 2 != 0:
    print(f"The number is odd")
# Out:
# Enter an integer number: -10
# The numberis even

# %% [markdown]
# 2. Ask the user to input a number (should be integer). Check whether the number is zero, positive or negative.

# %%
a = input ("Enter an integer number: ")
a = int(a)
if a == 0:
    print(f" The number is zero")
elif a > 0:
    print(f"The number is positive")
elif a < 0:
    print(f"The number is negative")
# Out:
# Enter an integer number: 0
#  The number is zero

# %% [markdown]
# 1.3 A school has following grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 60 - D
#
# d. 60 to 75 - C
#
# e. 75 to 90 - B
#
# f. Above 90 - A
#
# Ask user to enter marks (assuming the marks are between 0 and 100) and print the corresponding grade.

# %%
marks = input("Enter the marks (a number between 0 and 10): ")
marks = float(marks)

if marks >=0 and marks < 25:
    print("Grade: F")
elif marks >= 25 and marks < 45:
    print("Grade: E")
elif marks >= 45 and marks < 60:
    print("Grade: D")
elif marks >= 60 and marks < 75:
    print("Grade: C")
elif marks >= 75 and marks < 90:
    print("Grade: B")
else:
    print("Grade: A")
# Out:
# Enter the marks (a number between 0 and 10): 11.2
# Grade: F

# %% [markdown]
# Bonus: In the problem 1.1, we asked you to write a code to enter an integer and then check if that number is even or not. What if the user inputs a letter or some symbol instead? If we don’t handle this properly, code will break. We should prompt the user if the input entered was incorrect.
#
# Now try and make this code more robust by first checking if the entered input is a number or not. If the number entered is an integer, only then check if it is even or not.

# %%
a = input("Enter an integer number: ")

if a.isdigit() == True:
    a = int(a)

    if a == 0:
        print(f"0 is neither even nor odd")
    elif a % 2 == 0:
        print(f"The numberis even")
    elif a % 2 != 0:
        print(f"The number is odd")
else:
    print(f"Input is not an integer number")
# Out:
# Enter an integer number: 100.11
# Input is not an integer number
