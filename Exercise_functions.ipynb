# %% [markdown]
# # Exercise

# %% [markdown]
# Create a "generation calculator" to help determine the generation you belong to according to your birth year. Follow the below information:
#
# ```
# +-----------------+---------------------+
# |  birth_year     |      generation     |
# +-----------------+---------------------+
# |     < 1949      |  silent generation  |
# +-----------------+---------------------+
# |     < 1969      |     baby boomer     |
# +-----------------+---------------------+
# |     < 1981      |     X generation    |
# +-----------------+---------------------+
# |     < 1994      |      millennial     |
# +-----------------+---------------------+
# |     > 1994      |    Z generation     |
# +-----------------+---------------------+
# ```
#
# Let's add some "fake" users whose data we will be using to validate if the function gives us the correct and expected result.

# %%
# Generation What?

name1 = "Jonh"
birth_year1 = 1989

name2 = "Mari"
birth_year2 = 1995

name3 = "Mich"
birth_year3 = 1960

# %% [markdown]
# 1. Define the function generation calculator & add both parameters to represent both variables we are going to need in this function.
# 2. Determine generation as a birth year (we need to know the year to be able to calculate)
# 3. Print the results
# 4. Write conditionals for each generation. For example, if you were born before 1949 you would be a “silent generation”.
# 5. Define variables for each result
# 6. Show results

# %%
def generation_calculator (name, birth_year):
    generation = birth_year

    if generation < 1949:
        return name + "  belongs to the silent generation"
    elif generation < 1969:
        return name + " belongs to the baby boomer generation"
    elif generation < 1981:
        return name + " belongs to the X generation"
    elif generation < 1994:
        return name + " belongs to the millennial generation"
    else:
        return name + " belongs to the Z generation"

# %%
john_result = generation_calculator (name1, birth_year1)
mari_result = generation_calculator (name2, birth_year2)
mich_result = generation_calculator (name3, birth_year3)
print (mich_result,", ",mari_result,", and ", mich_result)
# Out:
# Mich belongs to the baby boomer generation ,  Mari belongs to the Z generation , and  Mich belongs to the baby boomer generation
